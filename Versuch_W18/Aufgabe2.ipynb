# %% [markdown]
# # Aufgabe 2
# ## Versuchsaufbau
# In Aufgabe 2 musste eine Ferromagnet in einem dünnen Rohr mit Hilfe einer Luftpumpe zum schweben gebracht. Der Aufbau bestand aus einem dünnen Glasrohr mit zwei öffnungne oben und unten um den Druck mittels einer Fahrradluftpumpe einzustellen. In der Glasrohre war ein genauso dicker Magnetzylinder und in der Mitte der Röhre wurde sie durch eine Spule umgeben. Wenn der Ferromagnet bei der Spule angekommen ist, musst die Frequenz so eingestellt werden, das es uzum Resonanzfall kam. So wurde optisch geschaut wann der Magnet am meisten schwingt. Dfür wurde der Versuch mehrmals wiederholt, da die Wechselstromquelle, sehr ungenau war.

# %% [markdown]
# ## Ermitlung der Resonanzfrequez
#
# Der Versuch wurde fünf mal durchgeführt, da das Wechselspannungsquelle eine sehr große Schwankungen vorwies. Deshalb wird als Resonanzfrequenz der Durchschnitt aller ermittelten Werte genommen.
#
# | $f$ [Hz] |
# |-------|
# | 21.44 |
# | 22.90 |
# | 24.44 |
# | 21.80 |
# | 20.90 |
# |Durchschnitt|
# | 22.296 |
#
# Barometer: 996,516 hPa
# Temperatur: 25.6°C

# %%
import pandas as pd
import numpy as np

daten = pd.read_csv("./daten/Aufgabe2.csv")

freq = daten["f [Hz]"]

print("Ausgerechnete gemittelte Frequenz: ", np.mean(freq))
# Out:
# Gemittelte Frequenz:  22.296

# %% [markdown]
# Der Adiabatenkoeffizien lässt sich berechnen mit der Formel (18) aus der Experimentierbeschreibung auf Moodle
# $$ \gamma = 297.1 (Pa \cdot s^2) \frac{f_0^2}{p_L}$$
# Dabei wird für $p_L=996.516$ hPa wie in Aufgabe 1 berechnet.
# Für die durchschnitts Resonanzfrequenz $f_0 = 22.296 Hz$
# $$\Rightarrow \gamma = 297.1 (Pa \cdot s^2) \frac{(22.296 \text{Hz})^2}{996.519 \cdot 10^2 \text{Pa}} \approx 1.482$$
#
# Zu Schluss muss aber noch erwähnt werden, das beim Experiment bestimme Näherungen gemacht wurden, so wurde der der Prozess in guter Näherung adiabatisch modeliert, das heißt $pV^\gamma = konst.$. AUch die Dipolwechselwirkung wurde nicht betrachtet und vernachlässigt. Zu den Näherungen wurden auh noch verschiedenste Annahmen gemacht, so dass die Rechnung einfacher ist. So wird die Verschiebung $x$ sehr klein ist vergliechen zu der  Höhe des Röhres über und unter der Dipol. Da der Dipol zudem mittig platziert werden sollte, kommte man zudem die Annahme machen, das oberhalb und unterhalb des Dipols der gelcihe Luftdruck herscht und das dieser ungefähr dem Druck außerhalb der Röhre entspricht. So kann es zu abweichungen zum Literaturwert kommen, was in [Aufgabe 3](#aufgabe-3) weiter diskutiert wird.
