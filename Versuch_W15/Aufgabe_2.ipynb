# %% [raw]
# ---
# title: "E4-Reale Spannungsquelle"
# author: "Fynn Kanja 3780065. Valentino D’Agosto 3763229"
# date: 12 06 2025
# date-format: "DD.MM.YYYY"
#
# jupyter: python3
# execute:
#   echo: false
#
# format:
#   pdf:
#     toc: true
#     toc-depth: 3
#     toc-title: Inhaltsverzeichnis
#
#     new-page: false
#
#     tbl-cap-location: bottom
#
#     fig-pos: "H"
#     fig-align: "center"
#
#     number-sections: true
#     number-depth: 3
#
#     colorlinks: true
#     documentclass: scrreprt
#     papersize: letter
# ---

# %% [markdown]
# # Aufgabenstellung
# 1. Nehmen Sie die Isothermen von $SF_6$ für acht Temperaturen auf. Eine Temperatur sollte oberhalb der kritischen Temperatur gewählt werden. Die Temperatur darf $55$°C nicht überschreiten, da sonst die Gefahr besteht, die Kapillare zu zerstören.
# 2. Zeichnen Sie die Isothermen und ermitteln Sie den Wert für den Sättigungsdruck ps im Bereich der Maxssssssswell-Geraden (Koexistenz von Flüssigkeit und Dampf).
# 3. Stellen Sie $ln(p_s)$ als Funktion von ($1/T$) graphisch dar. Passen Sie die Dampfdruckgleichung an die Daten an und bestimmen Sie die mittlere molare Verdampfungswärme der untersuchten Substanz.
# 4. Ermitteln Sie die Stoffmenge der untersuchten Substanz.
# 5. Bestimmen Sie die Verdampfungswärme als Funktion der Temperatur mittels der Clausius-Clapeyron-Gleichung. Stellen Sie die Verdampfungswärme als Funktion von $T/T_K$ graphisch dar und
# passen Sie ein Potenzgesetz an die Daten an.

# %% [markdown]
# # Aufgabe 2
# **Erklärung des Vorgehen bei Bestimmung und Eingehen auf Auffälligkeiten**
# Abweichung bei Volumina $\pm0.25\text{ml}$
# Abwecihung bei Druck $\pm25\text{kPa}$

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#TODO: Abweichung eintragen Plot Hübsch machen

# CSV einlesen
df1 = pd.read_csv('Daten/Isotherm_31_5.csv')
df2 = pd.read_csv('Daten/Isotherm_34_4.csv')
df3 = pd.read_csv('Daten/Isotherm_37_5.csv')
df4 = pd.read_csv('Daten/Isotherm_40_5.csv')
df5 = pd.read_csv('Daten/Isotherm_43_5.csv')
df6 = pd.read_csv('Daten/Isotherm_46_5.csv')
df7 = pd.read_csv('Daten/Isotherm_49_5.csv')
df8 = pd.read_csv('Daten/Isotherm_52_5.csv')

# Alle Daten in ein Array packen
volumen = [df1['V[ml]'], df2['V[ml]'], df3['V[ml]'], df4['V[ml]'], df5['V[ml]'], df6['V[ml]'], df7['V[ml]'], df8['V[ml]']]
druck = [df1['p [10^5 Pa]'], df2['p [10^5 Pa]'], df3['p [10^5 Pa]'],
         df4['p [10^5 Pa]'], df5['p [10^5 Pa]'], df6['p [10^5 Pa]'],
         df7['p [10^5 Pa]'], df8['p [10^5 Pa]']]
temperatur = [31.5, 34.4, 37.5, 40.5, 43.5, 46.5, 49.5, 52.5]



# Plot für die Messdaten
plt.figure(figsize=(20, 15))
fig, axs = plt.subplots(4,2)
axs = axs.flatten()
for i in range(len(axs)):
    #axs[i].set_xlim(0, 50)
    #axs[i].set_ylim(0, 1.5)
    axs[i].plot(volumen[i], druck[i], label=f"T = {temperatur[i]} °C")
    axs[i].set_title(f"Isotherm für $T = {temperatur[i]}$ °C")
    axs[i].set_xlabel("V [ml]")
    axs[i].set_ylabel("p [$10^5$ Pa]")
    axs[i].grid(True)
    axs[i].legend()

plt.xlabel("V [ml]")
plt.ylabel("p [$10^5$Pa]")
plt.tight_layout()
plt.show()
