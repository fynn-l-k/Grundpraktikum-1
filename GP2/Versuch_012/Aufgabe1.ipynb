# %% [raw]
# ---
# title: "O12 - Atomsprektren"
# author: "Fynn Kanja 3780065, Valentino D’Agosto 3763229"
# date: 24 10 2025
# date-format: "DD.MM.YYYY"
#
# jupyter: python3
# execute:
#   echo: false
#
# format:
#   pdf:
#     toc: true
#     toc-depth: 3
#     toc-title: Inhaltsverzeichnis
#
#     new-page: false
#
#     tbl-cap-location: top
#
#     fig-pos: "H"
#     fig-align: "center"
#
#     number-sections: true
#     number-depth: 3
#
#     colorlinks: true
#     documentclass: scrreprt
#     papersize: letter
# ---

# %% [markdown]
# # Aufgaben
# 1. Ermitteln Sie die Gitterkonstante eines Reflexionsgitters.
# Dazu sind das reflektierte Licht (0. Ordnung) sowie die ersten drei Beugungsordnungen der grünen
# Linie ($\lambda$ = 546.1 nm) einer Hg-Spektrallampe bei einer festen Gitteranordnung (etwa 60° zwischen
# einfallendem Licht und Gitternormale) auszumessen.
# 2. Bestimmen Sie die acht Wellenlängen von vier Dubletts des Spektrums einer Na-Spektrallampe aus
# dem Beugungsspektrum 1. Ordnung. Es ist dieselbe Gitteranordnung wie in Aufgabe 1 zu wählen.
# 3. Berechnen Sie das Auflösungsvermögen des Reflexionsgitters.
# Die wirksame Gitterbreite beträgt 50 mm (0.5%).

# %% [markdown]
# # Aufgabe 1
# ## Experimentaufbau
# ![Skizze vom Versuchsaufbau0](./Skizze.jpg){#fig-skizze}
#
# In unserem Experiment hatten wir, mithilfe des Präzisonsgoniometer-Spektrometer, $\varphi$ gemessen. $\alpha$ ist wie Abbildung 1 zeigt der Einfalswinkel ist, während $\beta$ der Ausfallswinkel ist. Dabei ist $\alpha$ über das ganze Experiment über konstant und nur $\varphi$ und $\beta$ ändern ihre größe.
#
# Um $\beta$ zu erhalten muss man $\beta = 180° - \varphi - \varphi_0 - \alpha$ berechnen. Der Winkel $\alpha$ ergibt sich dabei, wenn der Winkel $\varphi$ auf $\approx 60°$ eingestellt wird und das Maximum 0ter Ordnung mit dem Spiegel eingestellt wird. Dann gilt nähmlich $\alpha = \beta$, da der gesammt Strahl reflektiert wird, so kommt man auf die Formel, wobei $\varphi_{max} = 60.09°$ dem Winkel der ersten Ordnung entspricht.
# $$\alpha = \frac{180° - \varphi_{max} - \varphi_0}{2} = 60.1581°$$
#
# Da das Messgerät nicht genau auf der Nullstelle war als der Strahl das Fadenkreuz geschnitten hat, wurde ein Korrekturswinkel gemessen um die später aufgenommenen Daten zu korrigieren. Dieser lag bei uns, bei $359.5939°$ um nun den Korrekturwinkel $\varphi_0$ zu erhalten, rechnen wir folgendermaßen.
# $$\varphi_0 = 360° - 359.5939° = -0.4061°$$
# Da dies jedoch schwer einzuzeichnen war, ist dieser Winkel nicht in der Skizze zu finden.
#
# ## Ermittelung der Gitterkonstante
# In der ersten Aufgabe ging es darum die Gitterkonstante des Reflexionsgitters zu ermitteln. Dabei nutzeten wir eine die grünen Spektrallinien, mit einer Wellenlänge von $\lambda = 546.1$ nm einer Hg-Spektrallampe. Ermittelt wurde $\varphi$ sowie der Korrekturwinkel.
#
# Um nun auf die die Gitterkonstante zu kommen wird, die aus der Beschreibung des Experimentes die folgende Formel, der Phasendifferenz genommen.
# $$\delta = 2 \pi \frac{g(sin \alpha - sin \beta)}{\lambda}$$
# Dabei kann $\delta$ geschrieben werden als $\delta = 2k\pi$, wobei $k$ die Beugungsordnung ist ^[Diese Formel wurde aus dem Buch "Physikalischen Praktikum", 14. Auflage, Hrsg. W. Schenk, F. Kremer, Optik, 2.3, S.263 entnommen]. So lässt sich die vorherige Formel umstellen nach $g$.
# $$g = \frac{k \lambda}{sin \alpha - sin \beta}$$
# Mit dieser Formel, kann man nun die Gitterkonstante für jede Messung ausrechnen, was in der folgenden Tabelle gemacht wurde.
#
# In der Tabelle wurde mit den Rohwerten und mit den Korrekturwinkel $\varphi_0$ die Gitterkonstante $g$ berechnet.
#
#
# | Beugungsordnung | $\alpha$ | $\beta$ | $\varphi$ | $\varphi_0$ | g - Gitterkonstante (\$10\^{-6} m\$) |
# |------------|------------|------------|------------|------------|------------|
# | 0te | $59.955° \pm 2''$ | \$59.955°  \\pm 2'' \$ | \$60.09°\\pm 2''\$ | \$0°\$ | \- |
# | 0te mit Korrekturwinkel | $60.158° \pm 2''$ | $60.158° \pm 2''$ | $59.684° \pm 2''$ | \$0.4061° \\pm 2''\$ | \- |
# | 1te | $59.955° \pm 2''$ | \$30.775° \\pm 2''\$ | \$89.27°\\pm 2''\$ | \$0°\$ | $1.543$ |
# | 1te mit Korekturwinkel | $60.158° \pm 2''$ | $30.978° \pm 2''$ | $88.864° \pm 2''$ | \$0.4061° \\pm 2''\$ | $1.548$ |
# | 2te | $59.955° \pm 2''$ | \$8.985° \\pm 2''\$ | \$111.06°\\pm 2''\$ | \$0°\$ | $1.539$ |
# | 2te mit Korekturwinkel | $60.158° \pm 2''$ | $9.188° \pm 2''$ | \$ 110.654° \pm 2''\$ | \$0.4061° \\pm 2''\$ | $1.543$ |
# | 3te | $59.955° \pm 2''$ | \$-11.475° \\pm 2''\$ | \$131.52°\\pm 2''\$ | \$0°\$ | $1.539$ |
# | 3te mit Korekturwinkel | $60.158° \pm 2''$ | \$ -11.272° \pm 2''\$ | $131.114° \pm 2''$ |  | $1.541$ |
#
# : Tabelle mit allen bestimmten Winkeln, von der 0ten und 3ten Ordnung und die jeweilige Ermittelte Gitterkonstante
#
# Es ergibt sich so aus der Tabelle eine durchschnittliche Gitterkonstante von $1.540 \cdot 10 ^{-6}m$ ohne Korrekturwinkel und eine durchschnittliche Gitterkonstante von $1.544 \cdot 10 ^{-6}$. Dabei gilt ein relativer Fehler mit der Fehlerfortpflanzung von 0.15%.

# %%
# Gitterkonstante für alle Winkel
import numpy as np

korrektur_winkel = 0.4061

winkel_pro_ordnungszahl = np.array([89.27, 111.06, 131.52]) #phi
winkel_pro_ordnungszahl = winkel_pro_ordnungszahl - korrektur_winkel
erste_ordnung = 60.09 - korrektur_winkel #phi_0

alpha = (180 - erste_ordnung)/2 #minus korre
_lambda = 546.1 * 10**(-9)
def g(winkel, k):
    return (k * _lambda)/(np.sin(alpha * np.pi/180)-np.sin(winkel * np.pi/180))

gitter_konst = np.array([])

for i in range(len(winkel_pro_ordnungszahl)):
    print("BETA: ", 180 - winkel_pro_ordnungszahl[i] - alpha)
    gitter_konst = np.append(gitter_konst, g(180 - winkel_pro_ordnungszahl[i] - alpha, i + 1))

print(gitter_konst)
print(np.mean(np.abs(gitter_konst)))
print(alpha)
print(winkel_pro_ordnungszahl)
# Out:
# BETA:  30.978049999999996
# BETA:  9.18804999999999
# BETA:  -11.271950000000004
# [1.54837782e-06 1.54325250e-06 1.54139642e-06]
# 1.5443422436719798e-06
# 60.15805
# [ 88.8639 110.6539 131.1139]

# %% [markdown]
# ## Fehlerbetrachtung und Diskussion
# Da das Ablesen der Daten, optisch erfolgte, kann es zu Paralaxefehlern gekommen sein, da es nicht möglich ist, durch das Beobachtungsrohr perfekt zu schauen, kann es möglich sein, dass die Spektrallinie nicht immer genau in der Mitte des Fadenkreuz gewesen ist. Das gleiche gilt für das ablesen ders Gradmaßes, wobei dieses auch einen eigenen Messgenauigkeitsfehler von 2 Sekunden hat. Zudem war die Skala zum auslesen, vorallem die für die Minuten und Sekunden, an einigen stellen etwas verschmutzt was das Ablesen erschwierigte.
#
# Der maximale Fehler aus der Tabelle wurde mit einer Fehlerfortpflanzung berechnet, wobei für die Winkel eine Messunsicherheit von $2''$ Sekunden genommen wurde.
#
# Wie in der Tabelle zu sehen ist, kommen wir auf einen Durchschnittlichen Wert für die Gitterkonstante auf $g = 1.540 \cdot 10^{-6}m$ bzw. mit Korrekturwinkel von $g = 1.544 \cdot 10^{-6}m$ welcher sehr plausiebel ist. Da andere Reflexionsgitter, ähnliche Gitterkonstanten vorweisen.
