# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# CSV einlesen
df = pd.read_csv('Messdaten/Aufgabe3.csv')
df.columns = df.columns.str.replace('"', '').str.strip()



# Plot für a_x
plt.figure(figsize=(10, 4))
plt.plot((df['Pos_Kamera [mm]'])-df['Pos_Sys [mm]'], df['Skalierung'], color="blue")
plt.xlabel("Pos_Kamera - Pos_Sys [mm]")
plt.ylabel("Skalierung")
plt.title("Pos_Kamera - Pos_Sys vs Skalierung")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/v5/k7zv4p4953s9zf_j3p1qd2480000gn/T/ipykernel_41980/840761208.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
