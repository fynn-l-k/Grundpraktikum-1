# %% [markdown]
# # Aufgabe 1
#
# In Aufgabe 1 sollten wir eine Lampe und einen Schirm an feste Positionen stellen und dann für 2 verschiedenen Linsen jeweils die Stellen finden, an denen das Bild scharf ist. Mit den gemessenen Werten und dem Besselverfahren, können wir dann die Brennweiten der beiden Linsen berechnen. Folgende Werte haben wir gemessen und
# | Linse | Position Lampe (mit Korrektur) [mm]| Position Schirm [mm]  | Scharfe stelle $a$  [mm]| Scharfe Stelle $b$   [mm]   | $a$  [mm]|   $e$  [mm] |
# |--------:|------------:|------:|-----:|--------:|-----:|----------:|
# |1|40 $\implies$ 70|1300|225|1129|1230|904|
# |2|40 $\implies$ 70|1300|387|985|1230|598|
#
#
# ## Herleitung der Gleichung zum Bestimmen der Brennweiten $f_1$ und $f_2$ (Besselverfahren)
# Zur Bestimmung der Brennweiten $f_1$ und $f_2$ wurde, die Besselgleichung genommen. Da man dort die Variablen Bildabstand $b$ und Gestandsabstand $g$ nicht benötigt. Die Besselgleichung lautet für dünne Linsen wie folgt:
#
# $$f = \frac{s² - e²}{4s}$$
#
# Dabei ist $s=g+b$ der feste Abstand zwischen dem Schirm und dem Gegenstand und $e=s-2b$ der Abstand an dem die Linsen ihren Brennpunkt auf dem Schrim haben und ein scharfes Bild darauf zu erkennen ist.
#
# Für die Herleitung der Formel benötigen wir die Linsengleichung.
# $$\frac{1}{f} = \frac{1}{b} + \frac{1}{g}$$
# Durch einsetzen von $g = s - b$ und $b = (s - e)/2$ erhält man
# $$\frac{1}{f} = \frac{1}{(s - e)/2} + \frac{1}{s-(s - e)/2} = \frac{2}{s-e}+\frac{2}{a+e} = \frac{4s}{s²-e²}$$
# $$ \Longleftrightarrow f = \frac{s² - e²}{4s}$$
#
# Somit erhalten wir die Brennweiten: $f_1 = 141.4$ mm und $f_2 = 234.82$ mm.
