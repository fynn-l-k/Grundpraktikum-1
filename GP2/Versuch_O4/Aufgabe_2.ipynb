# %% [markdown]
# # Aufgabe 2
#
# ## Herleitung der Gleichung zum Bestimmen der Brennweiten $f_1$ und $f_2$
# Zur Bestimmung der Brennweiten $f_1$ und $f_2$ wurde, die Besselgleichung genommen. Da man dort die Variablen Bildabstand $b$ und Gestandsabstand $g$ nicht benötigt. Die Besselgleichung lautet für dünne Linsen wie folgt:
#
# $$f = \frac{s² - e²}{4s}$$
#
# Dabei ist $s=g+b$ der feste Abstand zwischen dem Schirm und dem Gegenstand und $e=s-2b$ der Abstand an dem die Linsen ihren Brennpunkt auf dem Schrim haben und ein scharfes Bild darauf zu erkennen ist.
#
# Für die Herleitung der Formel benötigen wir die Linsengleichung.
# $$\frac{1}{f} = \frac{1}{b} + \frac{1}{g}$$
# Durch einsetzen von $g = s - b$ und $b = (s - e)/2$ erhält man
# $$\frac{1}{f} = \frac{1}{(s - e)/2} + \frac{1}{s-(s - e)/2} = \frac{2}{s-e}+\frac{2}{a+e} = \frac{4s}{s²-e²}$$
# $$ \Longleftrightarrow f = \frac{s² - e²}{4s}$$
#
#
# Mit der folgenden Formel können wir dann, die Brennweite $f_{sys}$ für dass gesammt System erhalten. Dabei ist $f_n$ die Brennweite der $n$-ten Linse und $d_l$ der Abstand zwischen den beiden Linsen.
#
# $$\frac{1}{f_{sys}} = \frac{1}{f_1} + \frac{1}{f_2} - \frac{d_l}{f_1 f_2}$$
#
# So erhalten wir eine theoretische Systembrennweite von $f_{sys,t} = 205.95$ mm.
#
#
#
# ## Tabelle mit Messwerten
#
# | Linse | Positione Linse $a$ und $b$ \[mm\] | Position Schirm \[mm\] | Breinnweite $f_2$ \[mm\] |
# |----------|------------------------|------------------------|------------------------|
# | Linse 1 | $a = 225 ~~ b = 1129 \implies e = 904$ | $1300 \implies s = 1230$ | $f_1 = 141.40$ |
# | Linse 2 | $a = 387 ~~ b = 985 \implies e = 598$ | $1300 \implies s = 1230$ | $f_2 =234.82$ |
#
# : Tabelle mit den Messwerten, für den ersten Versuch. Wobei das Ziel war mittels der Besselgleichung, die Brennweite zu bestimmen. DIe Werte wurde schon alle mit dem Korrekturwert von $40$mm korrigiert.
#
# nach der obigen Besselgleichung für dünne Linsen, erhält man für die erste Linse eine Brennweite von $f_1 = 141.40$$ mm und für die Linse 2 eine Brennweite von $f_2 = 234.82$$ mm.
#
# Diese Werte wurden für den zweiten und dritten Versuch benötigt. Einmal zum kallebrieren der Skalierung in der Software und für mitunter den Vergleichswert in Aufgabe 3.
# Für den Versuch 3 ließen sich folgende, Messwerte ermitteln. Dabei wurden viele Messpunkte, im Abstand von mm aufgenommen, da am Anfang schwierigkeiten und Verwirrung auftauchten, bezüglich der Linsen und deren Verhalten mit Vergrößerung und Verkleinerung.
#
# **Muss hier noch Korrektur Faktor hinzugerechnet werden??**
#
# |Pos_Sys [mm]|Pos_Kamera [mm]|Skalierung|
# |------------|---------------|----------|
# |460         |613            |0.246     |
# |455         |611            |0.242     |
# |450         |610            |0.238     |
# |445         |607            |0.262     |
# |440         |607            |0.266     |
# |435         |606            |0.266     |
# |430         |605            |0.283     |
# |425         |604            |0.275     |
# |420         |603            |0.279     |
# |415         |603            |0.299     |
# |410         |604            |0.303     |
# |405         |603            |0.311     |
# |400         |604            |0.307     |
# |395         |605            |0.332     |
# |390         |605            |0.336     |
# |385         |607            |0.336     |
# |380         |610            |0.352     |
# |375         |611            |0.373     |
# |370         |613            |0.389     |
# |365         |617            |0.389     |
# |360         |620            |0.406     |
# |355         |624            |0.418     |
# |350         |629            |0.43      |
# |345         |636            |0.451     |
# |340         |643            |0.467     |
# |335         |649            |0.475     |
# |330         |657            |0.496     |
# |325         |665            |0.516     |
# |320         |676            |0.537     |
# |315         |687            |0.566     |
# |310         |701            |0.594     |
# |305         |719            |0.631     |
# |300         |738            |0.668     |
# |295         |757            |0.713     |
# |290         |781            |0.746     |
# |285         |810            |0.799     |
# |280         |843            |0.853     |
# |275         |887            |0.926     |
# |270         |929            |0.988     |
# |265         |987            |1.057     |
#
# : Messwerte aus Versuch 3, mit einem Linsensystem aus Linse 1 und Linse 2. Dabei wurden die Positionen der Kamera und die des Systems gemessen, sowie die Skalierung, die auf der Kamera zu sehen war.
#
# ## Vergleich mit Systembrennweite aus Aufgabe 1
# Bei Aufgabe 1 erhalten wir die Systembrennweiten $f_{sys}(g') = 200.631 \pm 2.017$ mm und $f_{sys}(b') = 203.295 \pm 1.109$ mm, diese beiden Werte sind sehr nah, selbst mit den Unsicherheiten, an unserem theoretischen Wert für die Systembrennweite von $f_{sys,t} = 205.95$ mm.
#
# Die kleine Abweichung vom theoretischen Ergbniss, zeigt dass wir sehr gute Messwerte haben. Was vermutlich durch die quantitativität der Messpunkte möglich ist. Da durch kann der Fit sich noch besser anpassen und die leichten Schwankungen am anfang so besser ausbessern.
# Außerdem können die vielen Messunsicherheiten auch zu dieser Abweichung führe. So wurden die Abstände immer auf einem Lineal auf der optischen Bank, abgelesen ($\pm 0.5$ mm). Zudem wurde in der Software, zwar versucht genau auf dem Punkt zu sein, bei der Skalierungsmessung. Jedoch hat dass mit dem TOuchpad des Laptops nicht immer einfach funktioniert, selbst beim besten willen, weshalb dort bestimmt eine Abweichung von $\pm 0.05$ mm dazugekommen ist. Zudem es außerdem ein optischer Versuch waren können auch Optische Fehler die Systembrennweite abweichen lassen, da der Experimentieraufbau nicht theoretissch ideal war. Es könnte zu sphärischer, chromischer Abberation oder zu Antistagmatismus gekommen sein, die die Kamera aufgefasst hat und welche die Werte leicht verändert.
