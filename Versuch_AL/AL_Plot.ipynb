# %% [markdown]
# # Plot Licht

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# CSV einlesen
df = pd.read_csv('arduino_data_3.csv')
df.columns = df.columns.str.replace('"', '').str.strip()

# Zeitspalte erzeugen
df['Zeitstempel'] = pd.to_datetime(
    df['Jahr'].astype(str) + "-" +
    df['Monat'].astype(str).str.zfill(2) + "-" +
    df['Tag'].astype(str).str.zfill(2) + " " +
    df['Stunde'].astype(str).str.zfill(2) + ":" +
    df['Minute'].astype(str).str.zfill(2) + ":" +
    df['Sekunde'].astype(str).str.zfill(2),
    format='%Y-%m-%d %H:%M:%S'
)

# Plot für a_x
plt.figure(figsize=(10, 4))
plt.plot(df['Zeitstempel'], df['Lux (lx)'], label="Licht", color="blue")
plt.xlabel("Zeit (Monat-Tag Stunde)")
plt.ylabel("Lux (lx))")
plt.title("Lichtstärke über Zeit")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot Temperatur

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# CSV einlesen
df = pd.read_csv('arduino_data_3.csv')
df.columns = df.columns.str.replace('"', '').str.strip()

# Zeitspalte erzeugen
df['Zeitstempel'] = pd.to_datetime(
    df['Jahr'].astype(str) + "-" +
    df['Monat'].astype(str).str.zfill(2) + "-" +
    df['Tag'].astype(str).str.zfill(2) + " " +
    df['Stunde'].astype(str).str.zfill(2) + ":" +
    df['Minute'].astype(str).str.zfill(2) + ":" +
    df['Sekunde'].astype(str).str.zfill(2),
    format='%Y-%m-%d %H:%M:%S'
)

# Plot für a_x
plt.figure(figsize=(10, 4))
plt.plot(df['Zeitstempel'], df['T (C)'], label="Temperatur", color="blue")
plt.xlabel("Zeit (Monat-Tag Stunde)")
plt.ylabel("T (C°)")
plt.title("Temperatur über Zeit")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot Druck

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# CSV einlesen
df = pd.read_csv('arduino_data_3.csv')
df.columns = df.columns.str.replace('"', '').str.strip()

# Zeitspalte erzeugen
df['Zeitstempel'] = pd.to_datetime(
    df['Jahr'].astype(str) + "-" +
    df['Monat'].astype(str).str.zfill(2) + "-" +
    df['Tag'].astype(str).str.zfill(2) + " " +
    df['Stunde'].astype(str).str.zfill(2) + ":" +
    df['Minute'].astype(str).str.zfill(2) + ":" +
    df['Sekunde'].astype(str).str.zfill(2),
    format='%Y-%m-%d %H:%M:%S'
)

# Plot für a_x
plt.figure(figsize=(10, 4))
plt.plot(df['Zeitstempel'], df['p (hPa)'], label="Druck", color="blue")
plt.xlabel("Zeit (Monat-Tag Stunde)")
plt.ylabel("p (Pa)")
plt.title("Druck über Zeit")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot Luftfeuchtigkeit

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# CSV einlesen
df = pd.read_csv('arduino_data_3.csv')
df.columns = df.columns.str.replace('"', '').str.strip()

# Zeitspalte erzeugen
df['Zeitstempel'] = pd.to_datetime(
    df['Jahr'].astype(str) + "-" +
    df['Monat'].astype(str).str.zfill(2) + "-" +
    df['Tag'].astype(str).str.zfill(2) + " " +
    df['Stunde'].astype(str).str.zfill(2) + ":" +
    df['Minute'].astype(str).str.zfill(2) + ":" +
    df['Sekunde'].astype(str).str.zfill(2),
    format='%Y-%m-%d %H:%M:%S'
)

# Plot für a_x
plt.figure(figsize=(10, 4))
plt.plot(df['Zeitstempel'], df['rH (%)'], label="Luftfeuchtigkeit", color="blue")
plt.xlabel("Zeit (Monat-Tag Stunde)")
plt.ylabel("rH (%)")
plt.title("Luftfeuchtigkeit über Zeit")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot CO2-Konzentration

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# CSV einlesen
df = pd.read_csv('arduino_data_3.csv')
df.columns = df.columns.str.replace('"', '').str.strip()

# Zeitspalte erzeugen
df['Zeitstempel'] = pd.to_datetime(
    df['Jahr'].astype(str) + "-" +
    df['Monat'].astype(str).str.zfill(2) + "-" +
    df['Tag'].astype(str).str.zfill(2) + " " +
    df['Stunde'].astype(str).str.zfill(2) + ":" +
    df['Minute'].astype(str).str.zfill(2) + ":" +
    df['Sekunde'].astype(str).str.zfill(2),
    format='%Y-%m-%d %H:%M:%S'
)

# Plot für a_x
plt.figure(figsize=(10, 4))
plt.plot(df['Zeitstempel'], df['CO2 (ppm)'], label="C02-Konzentration", color="blue")
plt.xlabel("Zeit (Monat-Tag Stunde)")
plt.ylabel("CO2 (ppm)")
plt.title("CO2-Konzentration über Zeit")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
